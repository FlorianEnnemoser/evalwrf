# %%
from evalwrf.geosphere_interface import load_csv
from evalwrf.postprocessing import plot_field, timeseries_station
import xarray as xr

# %%
da = xr.load_dataset("nwp.nc",decode_timedelta=True).squeeze()
fig = plot_field(da["t2m"],levels=10)

# %%
df = load_csv("murau_data.csv")
fig = timeseries_station(df, y="tl", title="Timeseries Murau Temperature")
